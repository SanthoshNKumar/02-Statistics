# %%
'''
Probability of Event A
Conditional Probability
Joint Probability
Union
Intersection
Complement
Bayes Theorem

# %%
'''
Probability
    - Probability is simply how likely something is to happen.
    - Probability is the branch of mathematics concerning numerical descriptions of how likely an event is to occur, or how 
      likely it is that a proposition is true.

# %%
'''
Difference between 'Statistics' and 'Probability'

    - Statistics is the science of looking at a given data and understanding the story of the data. On the other hand, 
      Probability is the study of the story and understanding the data behind it.

# %% [markdown]
# '''
# Applications of Probability
# Probability has a wide variety of applications in real life.
#
#     - Choosing a card from the deck of cards
#     - Flipping a coin
#     - Throwing a dice in the air
#     - Pulling a red ball out of a bucket of red and white balls
#     - Winning a lucky draw

# %%
'''
Probability of Event
    - We calculate probability depends on whether or not events A and B are independent or dependent.
    
If A and B are independent, then the formula we use to calculate P(A∩B) is: Joint Probability

# %% [markdown]
# ![probability10.JPG](attachment:probability10.JPG)

# %%
'''
If A and B are dependent, then the formula we use to calculate P(A∩B) is: Condtional Probability

# %% [markdown]
# ![probability11.JPG](attachment:probability11.JPG)

# %%
'''
Joint Probability (also called as 'Intersection')

    - Joint probability is a statistical measure that calculates the likelihood of two events occurring together and at the 
      same point in time. 

    - Joint probability is the probability of event Y occurring at the same time that event X occurs.

# %% [markdown]
# ![joint%20Probability.JPG](attachment:joint%20Probability.JPG)

# %% [markdown]
# ![joint%20Probability1.JPG](attachment:joint%20Probability1.JPG)

# %%
'''
Conditional Probability
    - When two events, A and B, are dependent, the probability of both occurring.
    - The probability of an event occurring given that another event has already occurred is called a conditional probability.

# %% [markdown]
# ![joint%20Probability1.JPG](attachment:joint%20Probability1.JPG)

# %%
'''
Other Operations

# %% [markdown]
# ![po.JPG](attachment:po.JPG)

# %%
'''
Union : P(A∪B)

# %%
'''
Intersection
    - It is as same as 'Joint Probability'

# %%
'''
Complement : P(A') = "Probability of the complement of Event A"

    Example: S = {1,2,3,4,5,6}
             A = {2,3,6}
             A' = {1,4,5}

# %%
'''
Bayes Theorem
    - Bayes Theorem can be used to calculate conditional probability

# %% [markdown]
# ![10%20Bayes%20Theorm.jpg](attachment:10%20Bayes%20Theorm.jpg)

# %%
'''
Prior Probability : (Before see the data)
    - It is the probability of an event before new data is collected.

# %%
'''
Posterior Probability:  (After seen the data)
    - It is the probability of assigning observations to groups given the data
    - Posterior probability = prior probability + new evidence (called likelihood).

# %% [markdown]
# ![joint%20Probability1.JPG](attachment:joint%20Probability1.JPG)

# %% [markdown]
# The posterior probability function (green) is received by multiplying the prior probability (red) times the likelihood (blue), divided by the evidence.

# %%
'''
PDF (Probability Density Function)
    - A function of a continuous random variable
    - The function of a distribution that shows the density of the values of our data is called a 'probability density function.
    - the probability density function produces the likelihood of values of the continuous random variable.
    
A function that defines the relationship between a random variable and its probability, such that you can find the probability 
of the variable using the function, is called a Probability Density Function (PDF) in statistics.

# %%
'''
Find the Probability Density Function in Statistics
    - Below are the are three main steps:
        - Summarizing the density with a histogram:
            - Plot the density function and compare histogram shape
            - Compare samples of the function with actual samples
            - Use a statistical test
        - Performing Parametric density estimation:
        - Performing Non-Parametric Density Estimation

# %%
'''
The probability density function (PDF) of a random variable, X, allows you to calculate the probability of an event
    - For continuous distributions, the probability that X has values in an interval (a, b) is precisely the area under 
      its PDF in the interval (a, b).
      
    - For discrete distributions, the probability that X has values in an interval (a, b) is exactly the sum of the 
      PDF (also called the probability mass function) of the possible discrete values of X in (a, b).

# %%
'''
The Cumulative Distribution Function (CDF)
The cumulative distribution function (CDF) is the probability that a random variable, say X, will take a value less than or 
equal to x
