# %%
'''
Log-normal Distribution
    - This distribution is used to plot the random variables whose logarithm values follow a normal distribution.
    - Consider the random variables X and Y. Y = ln(X) is the variable that is represented in this distribution, where ln 
      denotes the natural logarithm of values of X.

# %% [markdown]
# ![Log%20Normal%20Distribution.PNG](attachment:Log%20Normal%20Distribution.PNG)

# %%
'''
When should i go for Log Normal Distribution
- Skewed distributions with low mean values, large variance, and all-positive values often fit this type of distribution. 
  Values must be positive as log(x) exists only for positive values of x.

# %%
'''
Real time Example for Log Normal Distribution

1. The volume of gas in energy and petroleum reserve.
2. The volume of milk production.
3. The quantity of rainfall.

# %%
def pdf_lognormal(mu,sigma,x):
    pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2)) / (x * sigma * np.sqrt(2 * np.pi)))
    
    return pdf

# %%
mu, sigma = 3., 1. # mean and standard deviation
s = np.random.lognormal(mu, sigma, 1000)

import matplotlib.pyplot as plt
_, bins,_ = plt.hist(s, 100, density=True, align='mid')

x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2)) / (x * sigma * np.sqrt(2 * np.pi)))

plt.plot(x, pdf, linewidth=2, color='r')
plt.axis('tight')
plt.show()

# %%
from scipy.stats import lognorm

import numpy as np
import matplotlib.pyplot as plt


std = 0.5

print(lognorm.rvs(std))

data = lognorm.rvs(std, size=100000)

#print(data)
hx, hy, _ = plt.hist(data, bins=50, normed=1,color="lightblue")

plt.ylim(0.0,max(hx)+0.05)
plt.grid()
plt.show()

print(np.mean(data))
print(np.exp(std**2 / 2.0))

print(np.std(data))
var = (np.exp(std**2)-1)*np.exp(std**2)
print( np.sqrt(var) )
# Out:
# 2.8867788754067285
# c:\users\insakum46\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# 1.1348440497670877
# 1.1331484530668263
# 0.6065398566138174
# 0.6039005332108811
